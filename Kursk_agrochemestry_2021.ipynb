# %%
from preparing_script import data_processing_agrochem
import pandas as pd 
import numpy as np 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
year = 2021
agrochem_row = pd.read_excel("agrochemestry.xlsx")
agrochem_row = agrochem_row[agrochem_row['Год'] == year]

agrochem_row.columns
# Out:
# Index(['Unnamed: 0', 'рН солевой вытяжки, ед. рН', 'рН водной вытяжки, ед. рН',
#        'Фосфор (подвижная форма), мг/кг', 'Калий (подвижная форма), млн-1',
#        'Тип обработки', 'Общий азот, %', 'Органический углерод, %',
#        'Соотношение CN', 'Год', 'GPS №', 'Глубина'],
#       dtype='object')

# %% [markdown]
# подготовка данных из того что уже предобработанно

# %% [markdown]
# ## 2021

# %%
stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'рН солевой вытяжки, ед. рН', to_lable = "обработкам", by_points= 0)
fig.savefig(f'рН солевой вытяжки, ед. рН{year}.jpg',bbox_inches = 'tight' )

# %%
stats
# Out:
#                       рН солевой вытяжки, ед. рН
#                                              std variation   mean
# Тип обработки Глубина
# ПП            0-10                      0.092033  0.015626  5.268
#               10-20                     0.073621  0.012467  5.282
# ТТ            0-10                      0.118870  0.019711  5.394
#               10-20                     0.148997  0.025192  5.290

# %%
stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'рН водной вытяжки, ед. рН', to_lable = "обработкам", by_points= 0)
stats
fig.savefig(f'pH_вод_обработки{year}.jpg',bbox_inches = 'tight' )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-57d85f9be24f> in <module>
#       1 stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'рН водной вытяжки, ед. рН', to_lable = "обработкам", by_points= 0)
#       2 stats
# ----> 3 fig.savefig(f'pH_вод_обработки{year}.jpg',bbox_inches = 'tight' )
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2960                 patch.set_edgecolor('none')
#    2961
# -> 2962         self.canvas.print_figure(fname, **kwargs)
#    2963
#    2964         if transparent:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backends\backend_agg.py in print_jpg(self, filename_or_obj, pil_kwargs, *args, **kwargs)
#     562         try:
#     563             self.figure.set_facecolor(a * np.array([r, g, b]) + 1 - a)
# --> 564             FigureCanvasAgg.draw(self)
#     565         finally:
#     566             self.figure.set_facecolor((r, g, b, a))
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2735
#    2736             self.patch.draw(renderer)
# -> 2737             mimage._draw_list_compositing_images(
#    2738                 renderer, self, artists, self.suppressComposite)
#    2739
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2923             renderer.stop_rasterizing()
#    2924
# -> 2925         mimage._draw_list_compositing_images(renderer, self, artists)
#    2926
#    2927         renderer.close_group('axes')
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1142         self._update_label_position(renderer)
#    1143
# -> 1144         self.label.draw(renderer)
#    1145
#    1146         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     725                                           mtext=mtext)
#     726                 else:
# --> 727                     textrenderer.draw_text(gc, x, y, clean_line,
#     728                                            textobj._fontproperties, angle,
#     729                                            ismath=ismath, mtext=mtext)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backends\backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     201         # We pass '0' for angle here, since it will be rotated (in raster
#     202         # space) in the following call to draw_text_image).
# --> 203         font.set_text(s, 0, flags=flags)
#     204         font.draw_glyphs_to_bitmap(
#     205             antialiased=mpl.rcParams['text.antialiased'])
#
# KeyboardInterrupt:

# %%
stats
# Out:
#                       рН водной вытяжки, ед. рН
#                                             std variation   mean
# Тип обработки Глубина
# ПП            0-10                     0.127004  0.018399  6.174
#               10-20                    0.062290  0.008966  6.214
# ТТ            0-10                     0.103344  0.014823  6.236
#               10-20                    0.141315  0.020025  6.312

# %%
stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'Фосфор (подвижная форма), мг/кг', to_lable = "обработкам", by_points= 0)
stats
fig.savefig(f'фосфор_обработки{year}.jpg', bbox_inches = 'tight' )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-13aa7f57d008> in <module>
# ----> 1 stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'Фосфор (подвижная форма), мг/кг', to_lable = "обработкам", by_points= 0)
#       2 stats
#       3 fig.savefig(f'фосфор_обработки{year}.jpg', bbox_inches = 'tight' )
#
# d:\python_prj\курск 2022\preparing_script.py in data_processing_agrochem(df, type_, agrochem_property, to_lable, by_points)
#     104     aov = aov_for_nominal(df, agrochem_property, by_points)
#     105     stat_test_df = anova(df, type_, agrochem_property)
# --> 106     fig = ploting(df, type_, agrochem_property, aov,stat_test_df,to_lable  )
#     107
#     108     return(stats , aov, stat_test_df,fig )
#
# d:\python_prj\курск 2022\preparing_script.py in ploting(df, hue, agrochem_property, aov, stat_test_df, to_lable)
#      89     ax3.table(stat_test_df.values, colLabels = stat_test_df.columns ,loc='center')
#      90     ax3.set_title('ANOVA по глубинам \n {} '.format(to_lable),  y=0.75 , x = 0.5)
# ---> 91     plt.show(block=True)
#      92     return fig
#      93
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     352     """
#     353     _warn_if_gui_out_of_main_thread()
# --> 354     return _backend_mod.show(*args, **kwargs)
#     355
#     356
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44             )
#      45     finally:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     178     if _is_transparent(fig.get_facecolor()):
#     179         # the background is transparent
# --> 180         ticksLight = _is_light([label.get_color()
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     181                                 for axes in fig.axes
#     182                                 for axis in (axes.xaxis, axes.yaxis)
# --> 183                                 for label in axis.get_ticklabels()])
#     184         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     185             # there are one or more tick labels, all with the same lightness
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1219         if minor:
#    1220             return self.get_minorticklabels()
# -> 1221         return self.get_majorticklabels()
#    1222
#    1223     def get_majorticklines(self):
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1171     def get_majorticklabels(self):
#    1172         """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1173         ticks = self.get_major_ticks()
#    1174         labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#    1175         labels2 = [tick.label2 for tick in ticks if tick.label2.get_visible()]
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1346         while len(self.majorTicks) < numticks:
#    1347             # Update the new tick label properties from the old.
# -> 1348             tick = self._get_tick(major=True)
#    1349             self.majorTicks.append(tick)
#    1350             self._copy_tick_props(self.majorTicks[0], tick)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    2041         else:
#    2042             tick_kw = self._minor_tick_kw
# -> 2043         return XTick(self.axes, 0, major=major, **tick_kw)
#    2044
#    2045     def set_label_position(self, position):
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axis.py in __init__(self, *args, **kwargs)
#     418
#     419     def __init__(self, *args, **kwargs):
# --> 420         super().__init__(*args, **kwargs)
#     421         # x in data coords, y in axes coords
#     422         self.tick1line.set(
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     167             **grid_kw,
#     168         )
# --> 169         self.gridline.get_path()._interpolation_steps = \
#     170             GRIDLINE_INTERPOLATION_STEPS
#     171         self.label1 = mtext.Text(
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1020         """
#    1021         if self._invalidy or self._invalidx:
# -> 1022             self.recache()
#    1023         return self._path
#    1024
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     694             interpolation_steps = 1
#     695         xy = STEP_LOOKUP_MAP[self._drawstyle](*self._xy.T)
# --> 696         self._path = Path(np.asarray(xy).T,
#     697                           _interpolation_steps=interpolation_steps)
#     698         self._transformed_path = None
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# KeyboardInterrupt:

# %%
stats
# Out:
#                       Фосфор (подвижная форма), мг/кг
#                                                   std variation   mean
# Тип обработки Глубина
# ПП            0-10                          15.446780  0.235126  58.76
#               10-20                         11.141454  0.187952  53.02
# ТТ            0-10                          18.604247  0.278916  59.66
#               10-20                          9.084712  0.155902  52.12

# %%
stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'Калий (подвижная форма), млн-1', to_lable = "обработкам", by_points= 0)
stats
fig.savefig(f'калий_обработки{year}.jpg', bbox_inches = 'tight' )

# %%
stats
# Out:
#                       Калий (подвижная форма), млн-1
#                                                  std variation        mean
# Тип обработки Глубина
# ПП            0-10                         66.443955  0.291762  203.691275
#               10-20                        25.297017  0.125013  180.991300
# ТТ            0-10                         65.771306  0.269487  218.294832
#               10-20                        46.966053  0.209847  200.182819

# %%
stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'Общий азот, %', to_lable = "обработкам", by_points= 0)
fig.savefig(f'Общий азот{year}, %.jpg',bbox_inches = 'tight' )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-59650b03c5cf> in <module>
# ----> 1 stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'Общий азот, %', to_lable = "обработкам", by_points= 0)
#       2 fig.savefig(f'Общий азот{year}, %.jpg',bbox_inches = 'tight' )
#
# d:\python_prj\курск 2022\preparing_script.py in data_processing_agrochem(df, type_, agrochem_property, to_lable, by_points)
#     104     aov = aov_for_nominal(df, agrochem_property, by_points)
#     105     stat_test_df = anova(df, type_, agrochem_property)
# --> 106     fig = ploting(df, type_, agrochem_property, aov,stat_test_df,to_lable  )
#     107
#     108     return(stats , aov, stat_test_df,fig )
#
# d:\python_prj\курск 2022\preparing_script.py in ploting(df, hue, agrochem_property, aov, stat_test_df, to_lable)
#      89     ax3.table(stat_test_df.values, colLabels = stat_test_df.columns ,loc='center')
#      90     ax3.set_title('ANOVA по глубинам \n {} '.format(to_lable),  y=0.75 , x = 0.5)
# ---> 91     plt.show(block=True)
#      92     return fig
#      93
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     352     """
#     353     _warn_if_gui_out_of_main_thread()
# --> 354     return _backend_mod.show(*args, **kwargs)
#     355
#     356
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     506             *metadata*, including the default 'Software' key.
#     507         """
# --> 508         FigureCanvasAgg.draw(self)
#     509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     404              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     405               else nullcontext()):
# --> 406             self.figure.draw(self.renderer)
#     407             # A GUI class may be need to update a window using this draw, so
#     408             # don't forget to call the superclass.
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    2735
#    2736             self.patch.draw(renderer)
# -> 2737             mimage._draw_list_compositing_images(
#    2738                 renderer, self, artists, self.suppressComposite)
#    2739
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2923             renderer.stop_rasterizing()
#    2924
# -> 2925         mimage._draw_list_compositing_images(renderer, self, artists)
#    2926
#    2927         renderer.close_group('axes')
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer, *args, **kwargs)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\text.py in draw(self, renderer)
#     725                                           mtext=mtext)
#     726                 else:
# --> 727                     textrenderer.draw_text(gc, x, y, clean_line,
#     728                                            textobj._fontproperties, angle,
#     729                                            ismath=ismath, mtext=mtext)
#
# c:\Users\ermolaevNR\.conda\envs\GIS38\lib\site-packages\matplotlib\backends\backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     201         # We pass '0' for angle here, since it will be rotated (in raster
#     202         # space) in the following call to draw_text_image).
# --> 203         font.set_text(s, 0, flags=flags)
#     204         font.draw_glyphs_to_bitmap(
#     205             antialiased=mpl.rcParams['text.antialiased'])
#
# KeyboardInterrupt:

# %%
stats

# %%
stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'Органический углерод, %', to_lable = "обработкам", by_points= 0)
fig.savefig(f'Органический углерод{year}, %.jpg',bbox_inches = 'tight' )

# %%
stats

# %%
stats , aov, stat_test_df,fig = data_processing_agrochem(df = agrochem_row, type_ = 'Тип обработки', agrochem_property = 'Соотношение CN', to_lable = "обработкам", by_points= 0)
fig.savefig(f'Соотношение CN{year}.jpg',bbox_inches = 'tight' )

# %%
stats
